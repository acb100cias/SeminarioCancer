# %% [markdown]
# <a href="https://colab.research.google.com/github/acb100cias/SeminarioCancer/blob/main/ModelosCrecimiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# #Crecimiento ilimitado

# %%
gamma=0.1
def G(x,t):
  return gamma*x

# %%
gamma=.25
T=np.arange(0,200,0.001)
ci=1
sol=odeint(G,ci,T)

# %%
sol.T

# %%
T.shape

# %%
plt.plot(T,sol)

# %%
sol.T.shape

# %%
def G1(x,t):
  return gamma*x**alpha

# %%
alpha=0.1
gamma=0.1
ci=1
sol1=odeint(G1,ci,T)
plt.plot(T,sol1,label='Mendelsohn')
plt.plot(T,sol,label='Malthus')
plt.legend()

# %%
def G2(x,t):
  return gamma*x-delta*x*np.log(x)
def G3(x,t):
  return gamma*x-delta*x**2

# %%
delta=0.2
sol2=odeint(G2,ci,T)
sol3=odeint(G3,ci,T)
plt.plot(T,sol2,'o',label='Gompertz')
plt.plot(T,sol2,label='Verhulst')
plt.legend()

# %%
def G2(x,t):
  return gamma*x-delta*x*np.log(x/K)
def G3(x,t):
  return gamma*x*(1-delta*(x/K))
K=156
delta=0.2
sol2=odeint(G2,ci,T)
sol3=odeint(G3,ci,T)
plt.plot(T,sol2,'o',label='Gompertz')
plt.plot(T,sol2,label='Verhulst')
plt.legend()

# %%
def G4(x,t):
  return gamma*x*(1-(x/K)**nu)

nu=0.25
sol4=odeint(G4,ci,T)
plt.plot(T,sol4,label=r'logistica generalizada $\nu = 1/4$')
nu=0.5
sol5=odeint(G4,ci,T)
plt.plot(T,sol5,label=r'logistica generalizada $\nu = 1/2$')
plt.plot(T,sol3,label='logistica')
plt.legend()

# %%
def G6(x,t):
  return gamma*x*((K/x)**(1-alpha)-1)
alpha=2/3
sol6=odeint(G6,ci,T)
plt.plot(T,sol6,label='logistica potencial de Berthalanffy')
alpha=3/4
sol7=odeint(G6,ci,T)
plt.plot(T,sol7,label='logistica potencial de West-Brown-Enquist')
plt.plot(T,sol5,label=r'logistica generalizada $\nu = 1/2$')
#plt.plot(T,sol3,label='logistica')
plt.plot(T,sol4,label=r'logistica generalizada $\nu = 1/4$')

plt.legend()
